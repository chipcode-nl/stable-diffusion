# %%
# !pip3 install jupyter ipykernel ipywidgets
# !pip3 install torch numpy diffusers transformers scipy ftfy accelerate
# Out:
# Requirement already satisfied: jupyter in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (1.0.0)
# Requirement already satisfied: ipykernel in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (6.9.1)
# Requirement already satisfied: ipywidgets in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (7.6.5)
# Requirement already satisfied: notebook in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter) (6.4.11)
# Requirement already satisfied: nbconvert in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter) (6.4.4)
# Requirement already satisfied: jupyter-console in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter) (6.4.3)
# Requirement already satisfied: qtconsole in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter) (5.3.0)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (1.5.5)
# Requirement already satisfied: ipython>=7.23.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (8.3.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (6.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: appnope in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (1.5.1)
# Requirement already satisfied: traitlets<6.0,>=5.1.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipykernel) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: pickleshare in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: stack-data in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (65.6.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel) (2.11.2)
# Requirement already satisfied: pyzmq>=22.3 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (22.3.0)
# Requirement already satisfied: entrypoints in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (4.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel) (2.8.2)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets) (4.4.0)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from notebook->jupyter) (3.1.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from notebook->jupyter) (1.8.0)
# Requirement already satisfied: prometheus-client in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from notebook->jupyter) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from notebook->jupyter) (0.13.1)
# Requirement already satisfied: testpath in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (0.6.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: bleach in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: qtpy>=2.0.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from qtconsole->jupyter) (2.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jinja2->notebook->jupyter) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from python-dateutil>=2.8.2->jupyter-client<8.0->ipykernel) (1.16.0)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from qtpy>=2.0.1->qtconsole->jupyter) (21.3)
# Requirement already satisfied: cffi>=1.0.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from argon2-cffi->notebook->jupyter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.3.1)
# Requirement already satisfied: webencodings in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: executing in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: pure-eval in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: asttokens in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.5)
# Requirement already satisfied: pycparser in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from packaging->qtpy>=2.0.1->qtconsole->jupyter) (3.0.4)
# Requirement already satisfied: torch in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (1.23.5)
# Requirement already satisfied: diffusers in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: transformers in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (4.27.1)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: ftfy in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (6.1.1)
# Requirement already satisfied: accelerate in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: filelock in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from torch) (4.4.0)
# Requirement already satisfied: sympy in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from torch) (2.8.4)
# Requirement already satisfied: jinja2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: Pillow in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: importlib-metadata in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from diffusers) (6.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from diffusers) (2022.10.31)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from diffusers) (0.13.2)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from diffusers) (2.28.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from ftfy) (0.2.5)
# Requirement already satisfied: psutil in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from accelerate) (5.9.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from requests->diffusers) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from requests->diffusers) (1.26.14)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages (from sympy->torch) (1.2.1)

# %%
import os 
import torch
from diffusers import StableDiffusionPipeline

cache_dir = "cache.tmp"
os.makedirs(cache_dir, exist_ok=True)
os.makedirs("output.tmp", exist_ok=True)

model_name = "stabilityai/stable-diffusion-2-1"
pipe = StableDiffusionPipeline.from_pretrained(model_name, cache_dir= cache_dir)

if torch.backends.mps.is_available() and torch.backends.mps.is_built():
    # PyTorch device is Apple Metal Performance Shaders (mps)
    device = "mps"
elif torch.cuda.is_available():
    # PyTorch device is CUDA GPU 
    device = "cuda"
else:
    # PyTorch device is CPU  
    device = "cpu"

pipe.to(device)
device
# Out:
# Fetching 13 files:   0%|          | 0/13 [00:00<?, ?it/s]
# /opt/homebrew/Caskroom/miniconda/base/envs/torch_gpu/lib/python3.9/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# 'mps'

# %%
prompt = "Sailing ship in storm by Leonardo da Vinci"
negative_prompt = "ugly, tiling, poorly drawn hands, poorly drawn feet, poorly drawn face, out of frame, mutation, mutated, extra limbs, extra legs, extra arms, disfigured, deformed, cross-eye, body out of frame, blurry, bad art, bad anatomy, blurred, text, watermark, grainy"
width = 768
height = 768
guidance_scale = 7
steps = 50
seed = 1


generator = torch.Generator("cpu").manual_seed(seed)
image = pipe(
    prompt= prompt, 
    negative_prompt=negative_prompt, 
    width=width, height=height, 
    guidance_scale=guidance_scale, 
    num_inference_steps=steps,
    generator= generator
    ).images[0]

image.save("output.tmp/sailing_ship_v2_1_768x768.png")
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x768>
